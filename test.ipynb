# %%
import numpy as np
import os
from config.dir import DATA_DIR, EM_DATA_DIR,RESULTS_DATA_DIR,FEATURE_DATA_DIR
directory=os.path.join(RESULTS_DATA_DIR,'sub-UTS01','1','semantic_model')
loaded_array = np.load(os.path.join(directory,'scores_test.npy'))
np.argmax(loaded_array>0)
# Out:
# np.int64(4)

# %%
len(loaded_array)
# Out:
# 81126
